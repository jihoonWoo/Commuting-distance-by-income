# %% [markdown]
# # Prepare and setup insight
#
# Read data generated by "Commuting-Distance-by-Personal-Characteristics" [1] to prepare and setup data insight.

# %% [markdown]
# ## Download data
#
# 1. Go to (https://doi.org/10.5281/zenodo.4939860) and download the repository.
# 2. Unzip the repository on your working directory

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Read data

# %%
input_path = '../../DATA/Commuting-Distance-by-Personal-Characteristics/generated_data/'
input_file = 'transformed_data.xlsx'

# %%
df = pd.read_excel(input_path + input_file, usecols=[1, 2, 3], sheet_name='income')
df
# Out:
#     Average commuting distance \n(kilometres)  \
# 0                                       14.03
# 1                                       12.96
# 2                                        9.63
# 3                                       11.63
# 4                                       12.27
# 5                                       12.88
# 6                                       13.64
# 7                                       14.64
# 8                                       15.84
# 9                                       16.95
# 10                                      17.82
# 11                                      18.18
# 12                                      19.01
# 13                                      20.01
# 14                                      17.60
# 15                                      16.62
# 16                                      15.98
#
#                         Weekly Income (INCP)
# 0                            Negative income
# ...

# %% [markdown]
# The generated data contains the information about commuting distance in Australia in 2016. Column 'Weekly Income (INCP)' includes different weekly income groups, while 'Average commuting distance (kilometres)' column shows the average commuting distance for these income groups. The average commuting distance in Australia is 15.98km where weekly income group 2,000 - 2,999 has the highest average commuting distance (20.01).

# %% [markdown]
# ## Visualize data
#
# Here, we'd like to visualize the generated data. Below code demonstrates how to visualize the data by using Matplot library.
#
# **Matplot** : Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

x = list(df['Weekly Income (INCP)'])
AVG_distances = list(df['Average commuting distance \\n(kilometres)'])

x_pos = [i for i, _ in enumerate(x)]
plt.figure(figsize=(22,14))
plt.bar(x_pos, AVG_distances, color='#56C060')
plt.xlabel("Income", fontsize=22)
plt.ylabel("Kilometres", fontsize=22)
plt.title("Average commuting distance (km) by Income", fontsize=28)
plt.ylim((0, 25))   # set the ylim to bottom, top
for index, value in enumerate(AVG_distances):
    plt.text(index-0.4, value - 1, str(round(value, 2)), fontsize=18)

plt.xticks(x_pos, x, fontsize=18, rotation=90)

plt.savefig('img/Commuting distance by income.pdf', bbox_inches='tight')

plt.show()

# %% [markdown]
# The increased average daily commuting distance shows a positive correlation with increased average weekly income. Interestingly people earning in excess of \$3000 per week report a lower average daily commute than people in the previous four income brackets.

# %% [markdown]
# ## Insight
#
# **People making between 2,000 to 3000 dollars per week are likely to travel around 20km for daily commuting.**

# %%
value = float(df['Average commuting distance \\n(kilometres)'].loc[df['Weekly Income (INCP)'] == '2,000−2,999 (104,000−104,000−155,999)'])
print('People making between 2,000 to 3000 dollars per week are likely to travel around {}km for daily commuting.'.format(round(value, 2 )))
# Out:
# People making between 2,000 to 3000 dollars per week are likely to travel around 20.01km for daily commuting.

# %% [markdown]
# ## Conclusion
#
# We extract insight "People making between 2,000 to 3000 dollars per week are likely to travel around 20.01km for daily commuting." from the transformed data. The transformed data generated by [1] that it contains an analysis of the commuting distance by Personal Characteristics in Australia in 2016. The original data source of the transformed data is available at Australian Bureau of Statistics (ABS)[2].

# %% [markdown]
# ## References
#
# [1] Jihoon Woo, & Amir Aryani. (2021, June 13). ABS-Commuting-Distance-by-Personal-Characteristics (Version 1.0.1). Zenodo. http://doi.org/10.5281/zenodo.4939860
#
# [2] Australian Bureau of Statistics, 2071.0.55.001 - Census of Population and Housing: Commuting to Work - More Stories from the Census, Commuting Distance by Personal Characteristics, Australian Bureau of Statistics, 2018. [Dataset] Available: https://www.abs.gov.au/AUSSTATS/abs@.nsf/DetailsPage/2071.0.55.0012016?OpenDocument.
# [Accessed: January 4, 2021].
